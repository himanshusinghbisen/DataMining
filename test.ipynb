# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import sklearn.preprocessing    
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

features, _ = make_blobs(n_samples=100, centers=3
, n_features=2, random_state=42)
df = pd.DataFrame(features, columns=['Feature1', 'Feature2'])
clusterer = sklearn.cluster.KMeans(3, random_state=0)
clusterer.fit(features)
df['Cluster'] = clusterer.predict(features)
df.head()

# plt.scatter(df['Feature1'], df['Feature2'], cmap='viridis')
# plt.title("Synthetic Clusters via make_blobs")
# plt.show()
# Out:
#    Feature1  Feature2  Cluster
# 0 -7.726421 -8.394957        0
# 1  5.453396  0.742305        2
# 2 -2.978672  9.556846        1
# 3  6.042673  0.571319        2
# 4 -6.521840 -6.319325        0
